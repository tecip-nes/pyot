# %% [markdown]
# # PyoT RPL Information

# %% [markdown]
# ### Setup Environment and create a function to display images

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from networkx import *
from pyot.rplApp import *
from pyot.models import *
from IPython.display import Image, display
from networkx.algorithms import *



def pngShow(path):
    i = Image(filename=path)
    display(i)

# %% [markdown]
# ### Update a rpl graph on a running network

# %%
n = Network.objects.get(hostname='celery@cooja')

g = DAGupdate(n)
pngShow(g.getPNG())
# Out:
# Searching parents for resource:  aaaa::212:7407:7:707 - /rplinfo/parents
# Searching parents for resource:
#  aaaa::212:7405:5:505 - /rplinfo/parents
# Searching parents for resource:
#  aaaa::212:7409:9:909 - /rplinfo/parents
# Searching parents for resource:
#  aaaa::212:7402:2:202 - /rplinfo/parents
# Searching parents for resource:
#  aaaa::212:7408:8:808 - /rplinfo/parents
# Searching parents for resource:
#  aaaa::212:7406:6:606 - /rplinfo/parents
# Searching parents for resource:
#  aaaa::212:740a:a:a0a - /rplinfo/parents
# Searching parents for resource:
#  aaaa::212:7403:3:303 - /rplinfo/parents
# Searching parents for resource:
#  aaaa::212:7404:4:404 - /rplinfo/parents

# %% [markdown]
# ### nerworkx APIs

# %%
graph = g.graph
print info(graph)

print
print 'Number of inputs edges for each node'
print graph.in_degree()

print
print 'List of edges, nodoX -> nodoY'
print graph.out_edges()

print
print 'predecessor nodes for a specific node'
print '0909', graph.predecessors(':0909')
print '6LBR', graph.predecessors('6LBR')

print
print 'parents nodes'
print '0909', graph.successors(':0909')

print
print 'degree, numer of input/output edges for each node'
print graph.degree()



#for i in graph.degree_iter():
#    print i
print 
print 'Shortest path between all nodes and 6LBR'
for n in graph.nodes():
    p = shortest_path(graph, n, '6LBR')
    print n, p, 'hops = ', shortest_path_length(graph, n, '6LBR')

print
print 'Average shortest path length', average_shortest_path_length(graph)    

print
print 'network density= ', function.density(graph)
# Out:
# Name:
# Type: DiGraph
# Number of nodes: 10
# Number of edges: 9
# Average in degree:   0.9000
# Average out degree:   0.9000
#
# Number of inputs edges for each node
# {':0505': 0, ':0909': 2, ':0404': 0, '6LBR': 3, ':0202': 0, ':0707': 2, ':0303': 0, ':0a0a': 0, ':0606': 0, ':0808': 2}
#
# List of edges, nodoX -> nodoY
# [(':0505', ':0707'), (':0707', ':0909'), (':0202', '6LBR'), (':0909', '6LBR'), (':0303', '6LBR'), (':0a0a', ':0909'), (':0606', ':0808'), (':0808', ':0707'), (':0404', ':0808')]
#
# predecessor nodes for a specific node
# 0909 [':0707', ':0a0a']
# 6LBR [':0909', ':0202', ':0303']
#
# parents nodes
# 0909 ['6LBR']
#
# degree, numer of input/output edges for each node
# {':0505': 1, ':0909': 3, ':0404': 1, '6LBR': 3, ':0202': 1, ':0707': 3, ':0303': 1, ':0a0a': 1, ':0606': 1, ':0808': 3}
#
# Shortest path between all nodes and 6LBR
# :0505 [':0505', ':0707', ':0909', '6LBR'] hops =  3
# :0707 [':0707', ':0909', '6LBR'] hops =  2
# 6LBR ['6LBR'] hops =  0
# :0202 [':0202', '6LBR'] hops =  1
# :0909 [':0909', '6LBR'] hops =  1
# :0303 [':0303', '6LBR'] hops =  1
# :0a0a [':0a0a', ':0909', '6LBR'] hops =  2
# :0606 [':0606', ':0808', ':0707', ':0909', '6LBR'] hops =  4
# :0808 [':0808', ':0707', ':0909', '6LBR'] hops =  3
# :0404 [':0404', ':0808', ':0707', ':0909', '6LBR'] hops =  4
#
# Average shortest path length 0.455555555556
#
# network density=  0.1

# %% [markdown]
# ### Display a rpl graph on a network from the db, highlighting a set of nodes

# %%
cooja = Network.objects.get(hostname='cooja')

h = Host.objects.filter(kqueue=cooja)[2:7]
graph = RplGraph.objects.filter(net=cooja)[0]

pngShow(graph.getPNG(h))

# %% [markdown]
# ### Display a rpl graph on a network from the db, highlighting a single node

# %%
h = Host.objects.filter(kqueue__hostname='cooja')[0]
pngShow(graph.getPNG(h))
