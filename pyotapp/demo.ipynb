# %% [markdown]
# # PyoT & T-Res Demo

# %% [markdown]
# ### Setup the environment

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from networkx import *
from pyot.rplApp import *
from pyot.models import *
from IPython.display import Image, display
from networkx.algorithms import *
import numpy as np
import os
from pyot.models.tres import *
from pyot.tres.tresApp import *

def pngShow(path):
    i = Image(filename=path)
    display(i)

# %% [markdown]
# ### Dynamic RPL DAG visualizazion

# %%
n = Network.objects.get(hostname='celery@cooja')

g = DAGupdate(n)
pngShow(g.getPNG())
# Out:
# Searching parents for resource:  bbbb::212:7402:2:202 - /rplinfo/parents
# {"eui":"0212740100010101","pref":true,"etx":128}
# Searching parents for resource:  bbbb::212:740b:b:b0b - /rplinfo/parents
# {"eui":"0212740700070707","pref":true,"etx":128}
# Searching parents for resource:  bbbb::212:740a:a:a0a - /rplinfo/parents
# {"eui":"0212740200020202","pref":true,"etx":128}
# Searching parents for resource:  bbbb::212:7408:8:808 - /rplinfo/parents
# {"eui":"0212740900090909","pref":true,"etx":128}
# Searching parents for resource:  bbbb::212:7405:5:505 - /rplinfo/parents
# {"eui":"0212740700070707","pref":true,"etx":128}
# Searching parents for resource:  bbbb::212:7403:3:303 - /rplinfo/parents
# {"eui":"0212740100010101","pref":true,"etx":128}
# Searching parents for resource:  bbbb::212:7409:9:909 - /rplinfo/parents
# {"eui":"0212740100010101","pref":true,"etx":128}
# Searching parents for resource:  bbbb::212:7407:7:707 - /rplinfo/parents
# {"eui":"0212740900090909","pref":true,"etx":128}

# %% [markdown]
# ### Toggle actuators on every node

# %%
actuators = Resource.objects.filter(uri='/actuators/toggle', host__active=True, host__network__hostname='celery@cooja')

for act in actuators:
    act.POST()
    print 'toggling res: ' + str(act) 
print 'Done'
# Out:
# toggling res: bbbb::212:7402:2:202 - /actuators/toggle
# toggling res: bbbb::212:740b:b:b0b - /actuators/toggle
# toggling res: bbbb::212:740a:a:a0a - /actuators/toggle
# toggling res: bbbb::212:7408:8:808 - /actuators/toggle
# toggling res: bbbb::212:7405:5:505 - /actuators/toggle
# toggling res: bbbb::212:7403:3:303 - /actuators/toggle
# toggling res: bbbb::212:7409:9:909 - /actuators/toggle
# toggling res: bbbb::212:7407:7:707 - /actuators/toggle
# Done

# %% [markdown]
# ### Retrieve and display light values

# %%
r = Resource.objects.filter(uri='/sensors/light', host__active=True)
print r
y = []
y2 = []
for light in r:
    resp= light.GET()
    v = resp.content
    print light, v
    y.append(int(v.split(';')[0]))
    y2.append(int(v.split(';')[1]))

#plot everything
x = np.arange(len(r))
fig, axes = plt.subplots(nrows=1, ncols=2)
axes[0].bar(x, y, align="center", width=0.5, alpha=0.5)
axes[0].set_xlabel('Nodes')
axes[0].set_ylabel('lux')
axes[0].set_ylim(0, 200)
axes[0].set_title('Light sensor value 1')

axes[1].bar(x, y2, align="center", width=0.5, alpha=0.5)
axes[1].set_xlabel('Nodes')
axes[1].set_ylabel('lux')
axes[1].set_ylim(0, 200)
axes[1].set_title('Light sensor value 2')

fig.tight_layout()
# Out:
# [<Resource: bbbb::212:7402:2:202 - /sensors/light>, <Resource: bbbb::212:740b:b:b0b - /sensors/light>, <Resource: bbbb::212:740a:a:a0a - /sensors/light>, <Resource: bbbb::212:7408:8:808 - /sensors/light>, <Resource: bbbb::212:7405:5:505 - /sensors/light>, <Resource: bbbb::212:7403:3:303 - /sensors/light>, <Resource: bbbb::212:7409:9:909 - /sensors/light>, <Resource: bbbb::212:7407:7:707 - /sensors/light>]
# bbbb::212:7402:2:202 - /sensors/light
#  200;207
# bbbb::212:740b:b:b0b - /sensors/light
#  196;203
# bbbb::212:740a:a:a0a - /sensors/light
#  48;55
# bbbb::212:7408:8:808 - /sensors/light
#  168;175
# bbbb::212:7405:5:505 - /sensors/light
#  126;119
# bbbb::212:7403:3:303 - /sensors/light
#  146;153
# bbbb::212:7409:9:909 - /sensors/light
#  86;93
# bbbb::212:7407:7:707 - /sensors/light
#  144;137

# %% [markdown]
# # In-network processig with T-Res

# %% [markdown]
# ### Define a new processing function and install it on a T-Res Node

# %%
halve = """
from tres_pymite import *
print "Halve:",
i = getIntInput()
print i/2.
setOutput(i/2.)
"""

t1 = TResPF.fromSource(halve, 'halve')

rin = Resource.objects.filter(uri='/test/push', host__active=True, host__kqueue__hostname='celery@cooja-node1')
#rout = Resource.objects.filter(uri='/actuator', host__active=True)[0]
print rin

tresTask = TResTask(TresPf=t1, inputS=rin)
print tresTask


r = Resource.objects.get(uri='/tasks')
print r.host, '    is a t-res node'
tresTask.deploy(r)

# %% [markdown]
# ### Activate the task

# %%
tresTask.start()

# %% [markdown]
# ### Get the last output from the T-Res node

# %%
lo = tresTask.getLastOutput()
print lo.GET()

# %% [markdown]
# ### Stop the task

# %%
tresTask.stop()

# %% [markdown]
# ### Uninstall the task

# %%
tresTask.uninstall()
