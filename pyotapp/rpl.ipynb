# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from networkx import *
import matplotlib.image as mpimg

# %%
def pngShow(path):
    img=mpimg.imread(path)
    imgplot = plt.imshow(img)

# %%
from pyot.rplApp import *
n = Network.objects.all()[0]
g = DAGupdate(n)
pngShow(g.getPNG())
# Out:
# Searching parents for resource:  aaaa::212:7404:4:404 - /rplinfo/parents
# Searching parents for resource:
#  aaaa::212:7404:4:404 - /rplinfo/parents 1
# Searching parents for resource:
#  aaaa::212:740b:b:b0b - /rplinfo/parents
# Searching parents for resource:
#  aaaa::212:740b:b:b0b - /rplinfo/parents 1
# Searching parents for resource:
#  aaaa::212:7407:7:707 - /rplinfo/parents
# Searching parents for resource:
#  aaaa::212:7407:7:707 - /rplinfo/parents 1
# Searching parents for resource:
#  aaaa::212:7405:5:505 - /rplinfo/parents
# Searching parents for resource:
#  aaaa::212:7405:5:505 - /rplinfo/parents 1
# Searching parents for resource:
#  aaaa::212:7409:9:909 - /rplinfo/parents
# Searching parents for resource:
#  aaaa::212:7409:9:909 - /rplinfo/parents 1
# Searching parents for resource:
#  aaaa::212:7402:2:202 - /rplinfo/parents
# Searching parents for resource:
#  aaaa::212:7402:2:202 - /rplinfo/parents 1
# Searching parents for resource:
#  aaaa::212:7408:8:808 - /rplinfo/parents
# Searching parents for resource:
#  aaaa::212:7408:8:808 - /rplinfo/parents 1
# Searching parents for resource:
#  aaaa::212:7406:6:606 - /rplinfo/parents
# Searching parents for resource:
#  aaaa::212:7406:6:606 - /rplinfo/parents 1
# Searching parents for resource:
#  aaaa::212:740a:a:a0a - /rplinfo/parents
# Searching parents for resource:
#  aaaa::212:740a:a:a0a - /rplinfo/parents 1
# Searching parents for resource:
#  aaaa::212:7403:3:303 - /rplinfo/parents
# Searching parents for resource:
#  aaaa::212:7403:3:303 - /rplinfo/parents 1

# %%
graphs = RplGraph.objects.all()
for g in graphs:    
    pngShow(g.getPNG())
    print g.net.hostname
# Out:
# celery@cooja
# celery@cooja
# celery@cooja
# celery@cooja
# celery@cooja
