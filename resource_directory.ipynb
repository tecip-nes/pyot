# %%
from pyot.models import *
from pyot.tasks import coapRdServer
coapRdServer()
# Out:
# starting Coap Resource Directory Server, prefix= bbbb::/64
# CoAP Server start on [bbbb::1]:5683
# Message received from bbbb::1:38050
# ----------------------------------------
# Source: ('bbbb::1', 38050)
# Destination: None
# Type: CON
# MID: 12988
# Code: GET
# Token: �
# Uri-Path: .well-known
# Uri-Path: core
# Payload:
# None
#
# ----------------------------------------
# Message send to bbbb::1:38050
# ----------------------------------------
# Source: None
# Destination: ('bbbb::1', 38050)
# Type: ACK
# MID: 12988
# Code: CONTENT
# Token: �
# Content-Type: 40
# Payload:
# </rd>;rt="prova";sz="10";ct=0,
#
# ----------------------------------------
# Message received from bbbb::1:38046
# ----------------------------------------
# Source: ('bbbb::1', 38046)
# Destination: None
# Type: CON
# MID: 2
# Code: POST
# Token: None
# Uri-Path: rd
# Uri-Path: t
# Uri-Query: pyot
# Payload:
# /rd/t
#
# ----------------------------------------
# creating a virtual resource template.
# ...
